# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Feature engineering is the process of using domain knowledge to extract features from raw data via statistical techniques. These features will be used as the basis of machine learning models. Feature engineering is performed on the windowed time series data to convert the raw (time or frequency) signals into a set of informative characteristics.

# %% [markdown]
# ## Data Loading

# %% [markdown]
# Import the required libraries to perform feature selection.

# %%
import sys
import math
import numpy as np
import scipy as sp
import pandas as pd
sys.path.insert(1, '../src/')
from glob import glob
from utils import load_raw_data, load_dataset_data
from scipy.signal import medfilt
from scipy.fftpack import fft, fftfreq, ifft 
from statsmodels.robust import mad
from scipy.stats import iqr, entropy

# %% [markdown]
# Load the data using the functions defined earlier.

# %%
acc_df, gyro_df, label_df = load_raw_data()

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# We'll explore a basic set of features types that are applied to both the frequency and time signals.
# These features are a set of statistical measures that describe the time series.
#
# Rather than defining these features manually, you can often use existing Python libraries (e.g. tsfresh) to extract a large set of time series features (https://tsfresh.readthedocs.io/en/latest/text/list_of_features.html)

# %% [markdown]
# ### Common Axial Features

# %%
# the mean of the signal
def _mean(signal):
    return np.mean(signal)

# the standard deviation of the signal
def _std(signal):
    return np.std(signal)

# the median absolute deviation of the signal
def _mad(signal):
    return mad(signal)

# the max of the signal
def _max(signal):
    return np.max(signal)

# the min of the signal
def _min(signal):
    return np.min(signal)

# the interquantile range of the signal
def _iqr(signal):
    return iqr(signal)

# the entropy of the signal
def _entropy(signal):
    return entropy(signal+np.max(signal))

def calculate_signal_time_features(df, feature_cols, window_size = 30, sampling_frequency = 50):
    features_f = [_mean, _std, _mad, _max, _min, _iqr, _entropy]
    len_signal = len(df[feature_cols[0]].values)
    
    features = []
    for window in range(0, len_signal, sampling_frequency*window_size):
        window_features = [window]
        feature_names = ["window"]
        for signal in feature_cols:
            for feature in features_f:
                feature_names.append(signal+feature.__name__)
                window_features.append(feature(df[signal].values[window:window+window_size]))
        features.append(window_features)
    features_df = pd.DataFrame(data=features, columns=feature_names)

    return features_df

# %% [markdown]
# We'll calculate the features for an entire activity. The time series are first windowed (split into non-overlapping segments of length window_size) and we calculate the features for each of the different time windows.

# %%
features = calculate_signal_time_features(acc_df, ["acc_X", "acc_Y", "acc_Z"])
features
# Out:
#       window  acc_X_mean  acc_X_std  acc_X_mad  acc_X_max  acc_X_min  \
# 0          0    0.186620   0.019663   0.013385   0.238889   0.163889
# 1       1500    0.979676   0.001880   0.002059   0.984722   0.976389
# 2       3000    1.016898   0.002709   0.004118   1.023611   1.012500
# 3       4500    0.944769   0.002862   0.002059   0.950000   0.938889
# 4       6000    0.189167   0.002164   0.002059   0.193056   0.184722
# ..       ...         ...        ...        ...        ...        ...
# 744  1116000    0.993889   0.181121   0.157527   1.380556   0.654167
# 745  1117500    0.978009   0.125361   0.136935   1.233333   0.783333
# 746  1119000    0.996898   0.313886   0.279017   1.665278   0.488889
# 747  1120500    0.945370   0.239891   0.200769   1.656945   0.631944
# 748  1122000    1.009861   0.223182   0.280047   1.476389   0.736111
#
#      acc_X_iqr  acc_X_entropy  acc_Y_mean  acc_Y_std  ...  acc_Y_min  \
# 0     0.018750       3.400148    0.007361   0.019860  ...  -0.027778
# 1     0.002431       3.401197   -0.179167   0.002913  ...  -0.184722
# 2     0.004167       3.401197    0.083287   0.003237  ...   0.076389
# 3     0.003819       3.401196   -0.195648   0.002772  ...  -0.202778
# 4     0.002778       3.401181    0.561019   0.004332  ...   0.550000
# ..         ...            ...         ...        ...  ...        ...
# 744   0.253472       3.398283   -0.238194   0.197082  ...  -0.790278
# 745   0.176389       3.399603   -0.154537   0.166952  ...  -0.533333
# 746   0.304514       3.394306   -0.255370   0.183766  ...  -0.638889
# 747   0.298958       3.397088   -0.237593   0.158394  ...  -0.620833
# 748   0.358681       3.397216   -0.265648   0.143991  ...  -0.591667
#
#      acc_Y_iqr  acc_Y_entropy  acc_Z_mean  acc_Z_std  acc_Z_mad  acc_Z_max  \
# 0     0.036111       3.285185    0.985602   0.033895   0.029858   1.031945
# 1     0.004167       3.401163   -0.280324   0.005161   0.006178  -0.272222
# 2     0.002778       3.401020   -0.107546   0.005218   0.004118  -0.095833
# 3     0.002778       3.401172   -0.365231   0.004281   0.005148  -0.358333
# 4     0.006944       3.401190    0.815000   0.006732   0.007207   0.826389
# ..         ...            ...         ...        ...        ...        ...
# 744   0.237500           -inf   -0.026389   0.091415   0.047361   0.243056
# 745   0.167014           -inf    0.055926   0.088494   0.086485   0.193056
# 746   0.151389       3.228200   -0.032824   0.101505   0.077219   0.144444
# 747   0.183681       3.196823    0.085231   0.134957   0.162674   0.351389
# 748   0.210764       3.316803   -0.089537   0.064775   0.054568   0.026389
#
#      acc_Z_min  acc_Z_iqr  acc_Z_entropy
# 0     0.904167   0.044097       3.401056
# 1    -0.290278   0.009028       3.401154
# 2    -0.116667   0.006597       3.400868
# 3    -0.373611   0.006944       3.401180
# 4     0.798611   0.009375       3.401189
# ..         ...        ...            ...
# 744  -0.190278   0.069097       3.314550
# 745  -0.190278   0.099653       3.317437
# 746  -0.202778   0.126736           -inf
# 747  -0.109722   0.214931       3.353895
# 748  -0.243056   0.080208           -inf
#
# [749 rows x 22 columns]

# %% [markdown]
# From the current calculations, we end up with 22 computed features that describe the activity.

# %% [markdown]
# Let's investigate the range of features that have already been precalculated across all experiments.

# %%
X_train, y_train, subject_train, X_test, y_test, subject_test = load_dataset_data()
list(X_train.columns), len(list(X_train.columns))
# Out:
# (['tBodyAcc-Mean-1_0',
#   'tBodyAcc-Mean-2_1',
#   'tBodyAcc-Mean-3_2',
#   'tBodyAcc-STD-1_3',
#   'tBodyAcc-STD-2_4',
#   'tBodyAcc-STD-3_5',
#   'tBodyAcc-Mad-1_6',
#   'tBodyAcc-Mad-2_7',
#   'tBodyAcc-Mad-3_8',
#   'tBodyAcc-Max-1_9',
#   'tBodyAcc-Max-2_10',
#   'tBodyAcc-Max-3_11',
#   'tBodyAcc-Min-1_12',
#   'tBodyAcc-Min-2_13',
#   'tBodyAcc-Min-3_14',
#   'tBodyAcc-SMA-1_15',
#   'tBodyAcc-Energy-1_16',
#   'tBodyAcc-Energy-2_17',
#   'tBodyAcc-Energy-3_18',
#   'tBodyAcc-IQR-1_19',
#   'tBodyAcc-IQR-2_20',
#   'tBodyAcc-IQR-3_21',
#   'tBodyAcc-ropy-1_22',
#   'tBodyAcc-ropy-1_23',
#   'tBodyAcc-ropy-1_24',
#   'tBodyAcc-ARCoeff-1_25',
#   'tBodyAcc-ARCoeff-2_26',
#   'tBodyAcc-ARCoeff-3_27',
#   'tBodyAcc-ARCoeff-4_28',
#   'tBodyAcc-ARCoeff-5_29',
#   'tBodyAcc-ARCoeff-6_30',
#   'tBodyAcc-ARCoeff-7_31',
#   'tBodyAcc-ARCoeff-8_32',
#   'tBodyAcc-ARCoeff-9_33',
#   'tBodyAcc-ARCoeff-10_34',
#   'tBodyAcc-ARCoeff-11_35',
#   'tBodyAcc-ARCoeff-12_36',
#   'tBodyAcc-Correlation-1_37',
#   'tBodyAcc-Correlation-2_38',
#   'tBodyAcc-Correlation-3_39',
#   'tGravityAcc-Mean-1_40',
#   'tGravityAcc-Mean-2_41',
#   'tGravityAcc-Mean-3_42',
#   'tGravityAcc-STD-1_43',
#   'tGravityAcc-STD-2_44',
#   'tGravityAcc-STD-3_45',
#   'tGravityAcc-Mad-1_46',
#   'tGravityAcc-Mad-2_47',
#   'tGravityAcc-Mad-3_48',
#   'tGravityAcc-Max-1_49',
#   'tGravityAcc-Max-2_50',
#   'tGravityAcc-Max-3_51',
#   'tGravityAcc-Min-1_52',
#   'tGravityAcc-Min-2_53',
#   'tGravityAcc-Min-3_54',
#   'tGravityAcc-SMA-1_55',
#   'tGravityAcc-Energy-1_56',
#   'tGravityAcc-Energy-2_57',
#   'tGravityAcc-Energy-3_58',
#   'tGravityAcc-IQR-1_59',
#   'tGravityAcc-IQR-2_60',
#   'tGravityAcc-IQR-3_61',
#   'tGravityAcc-ropy-1_62',
#   'tGravityAcc-ropy-1_63',
#   'tGravityAcc-ropy-1_64',
#   'tGravityAcc-ARCoeff-1_65',
#   'tGravityAcc-ARCoeff-2_66',
#   'tGravityAcc-ARCoeff-3_67',
#   'tGravityAcc-ARCoeff-4_68',
#   'tGravityAcc-ARCoeff-5_69',
#   'tGravityAcc-ARCoeff-6_70',
#   'tGravityAcc-ARCoeff-7_71',
#   'tGravityAcc-ARCoeff-8_72',
#   'tGravityAcc-ARCoeff-9_73',
#   'tGravityAcc-ARCoeff-10_74',
#   'tGravityAcc-ARCoeff-11_75',
#   'tGravityAcc-ARCoeff-12_76',
#   'tGravityAcc-Correlation-1_77',
#   'tGravityAcc-Correlation-2_78',
#   'tGravityAcc-Correlation-3_79',
#   'tBodyAccJerk-Mean-1_80',
#   'tBodyAccJerk-Mean-2_81',
#   'tBodyAccJerk-Mean-3_82',
#   'tBodyAccJerk-STD-1_83',
#   'tBodyAccJerk-STD-2_84',
#   'tBodyAccJerk-STD-3_85',
#   'tBodyAccJerk-Mad-1_86',
#   'tBodyAccJerk-Mad-2_87',
#   'tBodyAccJerk-Mad-3_88',
#   'tBodyAccJerk-Max-1_89',
#   'tBodyAccJerk-Max-2_90',
#   'tBodyAccJerk-Max-3_91',
#   'tBodyAccJerk-Min-1_92',
#   'tBodyAccJerk-Min-2_93',
#   'tBodyAccJerk-Min-3_94',
#   'tBodyAccJerk-SMA-1_95',
#   'tBodyAccJerk-Energy-1_96',
#   'tBodyAccJerk-Energy-2_97',
#   'tBodyAccJerk-Energy-3_98',
#   'tBodyAccJerk-IQR-1_99',
#   'tBodyAccJerk-IQR-2_100',
#   'tBodyAccJerk-IQR-3_101',
#   'tBodyAccJerk-ropy-1_102',
#   'tBodyAccJerk-ropy-1_103',
#   'tBodyAccJerk-ropy-1_104',
#   'tBodyAccJerk-ARCoeff-1_105',
#   'tBodyAccJerk-ARCoeff-2_106',
#   'tBodyAccJerk-ARCoeff-3_107',
#   'tBodyAccJerk-ARCoeff-4_108',
#   'tBodyAccJerk-ARCoeff-5_109',
#   'tBodyAccJerk-ARCoeff-6_110',
#   'tBodyAccJerk-ARCoeff-7_111',
#   'tBodyAccJerk-ARCoeff-8_112',
#   'tBodyAccJerk-ARCoeff-9_113',
#   'tBodyAccJerk-ARCoeff-10_114',
#   'tBodyAccJerk-ARCoeff-11_115',
#   'tBodyAccJerk-ARCoeff-12_116',
#   'tBodyAccJerk-Correlation-1_117',
#   'tBodyAccJerk-Correlation-2_118',
#   'tBodyAccJerk-Correlation-3_119',
#   'tBodyGyro-Mean-1_120',
#   'tBodyGyro-Mean-2_121',
#   'tBodyGyro-Mean-3_122',
#   'tBodyGyro-STD-1_123',
#   'tBodyGyro-STD-2_124',
#   'tBodyGyro-STD-3_125',
#   'tBodyGyro-Mad-1_126',
#   'tBodyGyro-Mad-2_127',
#   'tBodyGyro-Mad-3_128',
#   'tBodyGyro-Max-1_129',
#   'tBodyGyro-Max-2_130',
#   'tBodyGyro-Max-3_131',
#   'tBodyGyro-Min-1_132',
#   'tBodyGyro-Min-2_133',
#   'tBodyGyro-Min-3_134',
#   'tBodyGyro-SMA-1_135',
#   'tBodyGyro-Energy-1_136',
#   'tBodyGyro-Energy-2_137',
#   'tBodyGyro-Energy-3_138',
#   'tBodyGyro-IQR-1_139',
#   'tBodyGyro-IQR-2_140',
#   'tBodyGyro-IQR-3_141',
#   'tBodyGyro-ropy-1_142',
#   'tBodyGyro-ropy-1_143',
#   'tBodyGyro-ropy-1_144',
#   'tBodyGyro-ARCoeff-1_145',
#   'tBodyGyro-ARCoeff-2_146',
#   'tBodyGyro-ARCoeff-3_147',
#   'tBodyGyro-ARCoeff-4_148',
#   'tBodyGyro-ARCoeff-5_149',
#   'tBodyGyro-ARCoeff-6_150',
#   'tBodyGyro-ARCoeff-7_151',
#   'tBodyGyro-ARCoeff-8_152',
#   'tBodyGyro-ARCoeff-9_153',
#   'tBodyGyro-ARCoeff-10_154',
#   'tBodyGyro-ARCoeff-11_155',
#   'tBodyGyro-ARCoeff-12_156',
#   'tBodyGyro-Correlation-1_157',
#   'tBodyGyro-Correlation-2_158',
#   'tBodyGyro-Correlation-3_159',
#   'tBodyGyroJerk-Mean-1_160',
#   'tBodyGyroJerk-Mean-2_161',
#   'tBodyGyroJerk-Mean-3_162',
#   'tBodyGyroJerk-STD-1_163',
#   'tBodyGyroJerk-STD-2_164',
#   'tBodyGyroJerk-STD-3_165',
#   'tBodyGyroJerk-Mad-1_166',
#   'tBodyGyroJerk-Mad-2_167',
#   'tBodyGyroJerk-Mad-3_168',
#   'tBodyGyroJerk-Max-1_169',
#   'tBodyGyroJerk-Max-2_170',
#   'tBodyGyroJerk-Max-3_171',
#   'tBodyGyroJerk-Min-1_172',
#   'tBodyGyroJerk-Min-2_173',
#   'tBodyGyroJerk-Min-3_174',
#   'tBodyGyroJerk-SMA-1_175',
#   'tBodyGyroJerk-Energy-1_176',
#   'tBodyGyroJerk-Energy-2_177',
#   'tBodyGyroJerk-Energy-3_178',
#   'tBodyGyroJerk-IQR-1_179',
#   'tBodyGyroJerk-IQR-2_180',
#   'tBodyGyroJerk-IQR-3_181',
#   'tBodyGyroJerk-ropy-1_182',
#   'tBodyGyroJerk-ropy-1_183',
#   'tBodyGyroJerk-ropy-1_184',
#   'tBodyGyroJerk-ARCoeff-1_185',
#   'tBodyGyroJerk-ARCoeff-2_186',
#   'tBodyGyroJerk-ARCoeff-3_187',
#   'tBodyGyroJerk-ARCoeff-4_188',
#   'tBodyGyroJerk-ARCoeff-5_189',
#   'tBodyGyroJerk-ARCoeff-6_190',
#   'tBodyGyroJerk-ARCoeff-7_191',
#   'tBodyGyroJerk-ARCoeff-8_192',
#   'tBodyGyroJerk-ARCoeff-9_193',
#   'tBodyGyroJerk-ARCoeff-10_194',
#   'tBodyGyroJerk-ARCoeff-11_195',
#   'tBodyGyroJerk-ARCoeff-12_196',
#   'tBodyGyroJerk-Correlation-1_197',
#   'tBodyGyroJerk-Correlation-2_198',
#   'tBodyGyroJerk-Correlation-3_199',
#   'tBodyAccMag-Mean-1_200',
#   'tBodyAccMag-STD-1_201',
#   'tBodyAccMag-Mad-1_202',
#   'tBodyAccMag-Max-1_203',
#   'tBodyAccMag-Min-1_204',
#   'tBodyAccMag-SMA-1_205',
#   'tBodyAccMag-Energy-1_206',
#   'tBodyAccMag-IQR-1_207',
#   'tBodyAccMag-ropy-1_208',
#   'tBodyAccMag-ARCoeff-1_209',
#   'tBodyAccMag-ARCoeff-2_210',
#   'tBodyAccMag-ARCoeff-3_211',
#   'tBodyAccMag-ARCoeff-4_212',
#   'tGravityAccMag-Mean-1_213',
#   'tGravityAccMag-STD-1_214',
#   'tGravityAccMag-Mad-1_215',
#   'tGravityAccMag-Max-1_216',
#   'tGravityAccMag-Min-1_217',
#   'tGravityAccMag-SMA-1_218',
#   'tGravityAccMag-Energy-1_219',
#   'tGravityAccMag-IQR-1_220',
#   'tGravityAccMag-ropy-1_221',
#   'tGravityAccMag-ARCoeff-1_222',
#   'tGravityAccMag-ARCoeff-2_223',
#   'tGravityAccMag-ARCoeff-3_224',
#   'tGravityAccMag-ARCoeff-4_225',
#   'tBodyAccJerkMag-Mean-1_226',
#   'tBodyAccJerkMag-STD-1_227',
#   'tBodyAccJerkMag-Mad-1_228',
#   'tBodyAccJerkMag-Max-1_229',
#   'tBodyAccJerkMag-Min-1_230',
#   'tBodyAccJerkMag-SMA-1_231',
#   'tBodyAccJerkMag-Energy-1_232',
#   'tBodyAccJerkMag-IQR-1_233',
#   'tBodyAccJerkMag-ropy-1_234',
#   'tBodyAccJerkMag-ARCoeff-1_235',
#   'tBodyAccJerkMag-ARCoeff-2_236',
#   'tBodyAccJerkMag-ARCoeff-3_237',
#   'tBodyAccJerkMag-ARCoeff-4_238',
#   'tBodyGyroMag-Mean-1_239',
#   'tBodyGyroMag-STD-1_240',
#   'tBodyGyroMag-Mad-1_241',
#   'tBodyGyroMag-Max-1_242',
#   'tBodyGyroMag-Min-1_243',
#   'tBodyGyroMag-SMA-1_244',
#   'tBodyGyroMag-Energy-1_245',
#   'tBodyGyroMag-IQR-1_246',
#   'tBodyGyroMag-ropy-1_247',
#   'tBodyGyroMag-ARCoeff-1_248',
#   'tBodyGyroMag-ARCoeff-2_249',
#   'tBodyGyroMag-ARCoeff-3_250',
#   'tBodyGyroMag-ARCoeff-4_251',
#   'tBodyGyroJerkMag-Mean-1_252',
#   'tBodyGyroJerkMag-STD-1_253',
#   'tBodyGyroJerkMag-Mad-1_254',
#   'tBodyGyroJerkMag-Max-1_255',
#   'tBodyGyroJerkMag-Min-1_256',
#   'tBodyGyroJerkMag-SMA-1_257',
#   'tBodyGyroJerkMag-Energy-1_258',
#   'tBodyGyroJerkMag-IQR-1_259',
#   'tBodyGyroJerkMag-ropy-1_260',
#   'tBodyGyroJerkMag-ARCoeff-1_261',
#   'tBodyGyroJerkMag-ARCoeff-2_262',
#   'tBodyGyroJerkMag-ARCoeff-3_263',
#   'tBodyGyroJerkMag-ARCoeff-4_264',
#   'fBodyAcc-Mean-1_265',
#   'fBodyAcc-Mean-2_266',
#   'fBodyAcc-Mean-3_267',
#   'fBodyAcc-STD-1_268',
#   'fBodyAcc-STD-2_269',
#   'fBodyAcc-STD-3_270',
#   'fBodyAcc-Mad-1_271',
#   'fBodyAcc-Mad-2_272',
#   'fBodyAcc-Mad-3_273',
#   'fBodyAcc-Max-1_274',
#   'fBodyAcc-Max-2_275',
#   'fBodyAcc-Max-3_276',
#   'fBodyAcc-Min-1_277',
#   'fBodyAcc-Min-2_278',
#   'fBodyAcc-Min-3_279',
#   'fBodyAcc-SMA-1_280',
#   'fBodyAcc-Energy-1_281',
#   'fBodyAcc-Energy-2_282',
#   'fBodyAcc-Energy-3_283',
#   'fBodyAcc-IQR-1_284',
#   'fBodyAcc-IQR-2_285',
#   'fBodyAcc-IQR-3_286',
#   'fBodyAcc-ropy-1_287',
#   'fBodyAcc-ropy-1_288',
#   'fBodyAcc-ropy-1_289',
#   'fBodyAcc-MaxInds-1_290',
#   'fBodyAcc-MaxInds-2_291',
#   'fBodyAcc-MaxInds-3_292',
#   'fBodyAcc-MeanFreq-1_293',
#   'fBodyAcc-MeanFreq-2_294',
#   'fBodyAcc-MeanFreq-3_295',
#   'fBodyAcc-Skewness-1_296',
#   'fBodyAcc-Kurtosis-1_297',
#   'fBodyAcc-Skewness-1_298',
#   'fBodyAcc-Kurtosis-1_299',
#   'fBodyAcc-Skewness-1_300',
#   'fBodyAcc-Kurtosis-1_301',
#   'fBodyAcc-BandsEnergyOld-1_302',
#   'fBodyAcc-BandsEnergyOld-2_303',
#   'fBodyAcc-BandsEnergyOld-3_304',
#   'fBodyAcc-BandsEnergyOld-4_305',
#   'fBodyAcc-BandsEnergyOld-5_306',
#   'fBodyAcc-BandsEnergyOld-6_307',
#   'fBodyGyro-Min-1_435',
#   'fBodyGyro-Min-2_436',
#   'fBodyGyro-Min-3_437',
#   'fBodyGyro-SMA-1_438',
#   'fBodyGyro-Energy-1_439',
#   'fBodyGyro-Energy-2_440',
#   'fBodyGyro-Energy-3_441',
#   'fBodyGyro-IQR-1_442',
#   'fBodyGyro-IQR-2_443',
#   'fBodyGyro-IQR-3_444',
#   'fBodyGyro-ropy-1_445',
#   'fBodyGyro-ropy-1_446',
#   'fBodyGyro-ropy-1_447',
#   'fBodyGyro-MaxInds-1_448',
#   'fBodyGyro-MaxInds-2_449',
#   'fBodyGyro-MaxInds-3_450',
#   'fBodyGyro-MeanFreq-1_451',
#   'fBodyGyro-MeanFreq-2_452',
#   'fBodyGyro-MeanFreq-3_453',
#   'fBodyGyro-Skewness-1_454',
#   'fBodyGyro-Kurtosis-1_455',
#   'fBodyGyro-Skewness-1_456',
#   'fBodyGyro-Kurtosis-1_457',
#   'fBodyGyro-Skewness-1_458',
#   'fBodyGyro-Kurtosis-1_459',
#   'fBodyGyro-BandsEnergyOld-1_460',
#   'fBodyGyro-BandsEnergyOld-2_461',
#   'fBodyGyro-BandsEnergyOld-3_462',
#   'fBodyGyro-BandsEnergyOld-4_463',
#   'fBodyGyro-BandsEnergyOld-5_464',
#   'fBodyGyro-BandsEnergyOld-6_465',
#   'fBodyGyro-BandsEnergyOld-7_466',
#   'fBodyGyro-BandsEnergyOld-8_467',
#   'fBodyGyro-BandsEnergyOld-9_468',
#   'fBodyGyro-BandsEnergyOld-10_469',
#   'fBodyGyro-BandsEnergyOld-11_470',
#   'fBodyGyro-BandsEnergyOld-12_471',
#   'fBodyGyro-BandsEnergyOld-13_472',
#   'fBodyGyro-BandsEnergyOld-14_473',
#   'fBodyGyro-BandsEnergyOld-15_474',
#   'fBodyGyro-BandsEnergyOld-16_475',
#   'fBodyGyro-BandsEnergyOld-17_476',
#   'fBodyGyro-BandsEnergyOld-18_477',
#   'fBodyGyro-BandsEnergyOld-19_478',
#   'fBodyGyro-BandsEnergyOld-20_479',
#   'fBodyGyro-BandsEnergyOld-21_480',
#   'fBodyGyro-BandsEnergyOld-22_481',
#   'fBodyGyro-BandsEnergyOld-23_482',
#   'fBodyGyro-BandsEnergyOld-24_483',
#   'fBodyGyro-BandsEnergyOld-25_484',
#   'fBodyGyro-BandsEnergyOld-26_485',
#   'fBodyGyro-BandsEnergyOld-27_486',
#   'fBodyGyro-BandsEnergyOld-28_487',
#   'fBodyGyro-BandsEnergyOld-29_488',
#   'fBodyGyro-BandsEnergyOld-30_489',
#   'fBodyGyro-BandsEnergyOld-31_490',
#   'fBodyGyro-BandsEnergyOld-32_491',
#   'fBodyGyro-BandsEnergyOld-33_492',
#   'fBodyGyro-BandsEnergyOld-34_493',
#   'fBodyGyro-BandsEnergyOld-35_494',
#   'fBodyGyro-BandsEnergyOld-36_495',
#   'fBodyGyro-BandsEnergyOld-37_496',
#   'fBodyGyro-BandsEnergyOld-38_497',
#   'fBodyGyro-BandsEnergyOld-39_498',
#   'fBodyGyro-BandsEnergyOld-40_499',
#   'fBodyGyro-BandsEnergyOld-41_500',
#   'fBodyGyro-BandsEnergyOld-42_501',
#   'fBodyAccMag-Mean-1_502',
#   'fBodyAccMag-STD-1_503',
#   'fBodyAccMag-Mad-1_504',
#   'fBodyAccMag-Max-1_505',
#   'fBodyAccMag-Min-1_506',
#   'fBodyAccMag-SMA-1_507',
#   'fBodyAccMag-Energy-1_508',
#   'fBodyAccMag-IQR-1_509',
#   'fBodyAccMag-ropy-1_510',
#   'fBodyAccMag-MaxInds-1_511',
#   'fBodyAccMag-MeanFreq-1_512',
#   'fBodyAccMag-Skewness-1_513',
#   'fBodyAccMag-Kurtosis-1_514',
#   'fBodyAccJerkMag-Mean-1_515',
#   'fBodyAccJerkMag-STD-1_516',
#   'fBodyAccJerkMag-Mad-1_517',
#   'fBodyAccJerkMag-Max-1_518',
#   'fBodyAccJerkMag-Min-1_519',
#   'fBodyAccJerkMag-SMA-1_520',
#   'fBodyAccJerkMag-Energy-1_521',
#   'fBodyAccJerkMag-IQR-1_522',
#   'fBodyAccJerkMag-ropy-1_523',
#   'fBodyAccJerkMag-MaxInds-1_524',
#   'fBodyAccJerkMag-MeanFreq-1_525',
#   'fBodyAccJerkMag-Skewness-1_526',
#   'fBodyAccJerkMag-Kurtosis-1_527',
#   'fBodyGyroMag-Mean-1_528',
#   'fBodyGyroMag-STD-1_529',
#   'fBodyGyroMag-Mad-1_530',
#   'fBodyGyroMag-Max-1_531',
#   'fBodyGyroMag-Min-1_532',
#   'fBodyGyroMag-SMA-1_533',
#   'fBodyGyroMag-Energy-1_534',
#   'fBodyGyroMag-IQR-1_535',
#   'fBodyGyroMag-ropy-1_536',
#   'fBodyGyroMag-MaxInds-1_537',
#   'fBodyGyroMag-MeanFreq-1_538',
#   'fBodyGyroMag-Skewness-1_539',
#   'fBodyGyroMag-Kurtosis-1_540',
#   'fBodyGyroJerkMag-Mean-1_541',
#   'fBodyGyroJerkMag-STD-1_542',
#   'fBodyGyroJerkMag-Mad-1_543',
#   'fBodyGyroJerkMag-Max-1_544',
#   'fBodyGyroJerkMag-Min-1_545',
#   'fBodyGyroJerkMag-SMA-1_546',
#   'fBodyGyroJerkMag-Energy-1_547',
#   'fBodyGyroJerkMag-IQR-1_548',
#   'fBodyGyroJerkMag-ropy-1_549',
#   'fBodyGyroJerkMag-MaxInds-1_550',
#   'fBodyGyroJerkMag-MeanFreq-1_551',
#   'fBodyGyroJerkMag-Skewness-1_552',
#   'fBodyGyroJerkMag-Kurtosis-1_553',
#   'tBodyAcc-AngleWRTGravity-1_554',
#   'tBodyAccJerk-AngleWRTGravity-1_555',
#   'tBodyGyro-AngleWRTGravity-1_556',
#   'tBodyGyroJerk-AngleWRTGravity-1_557',
#   'tXAxisAcc-AngleWRTGravity-1_558',
#   'tYAxisAcc-AngleWRTGravity-1_559',
#   'tZAxisAcc-AngleWRTGravity-1_560'],
#  561)

# %% [markdown]
# The features we've extracted so far have only been calculated in the time domain, and not the frequency domain. Additionally, a larger range of features have been calculated (e.g. 'Energy', 'SMA, 'ARCoeff', 'Kurtosis'), resulting in a total of 561 features.
#
# In the next notebooks, we'll investigate how an activity classifier can be built on top of these features.
